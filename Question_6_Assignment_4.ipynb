# %% [markdown]
# <a href="https://colab.research.google.com/github/Alton1998/University-Notes/blob/main/Question_6_Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import fft2,fftshift
from matplotlib.colors import LogNorm

# %%
image = plt.imread("GkTemple1200x800g.jpg")

# %%
image.shape
# Out:
# (800, 1200)

# %%
plt.imshow(image)

# %%
centralized_fft = fftshift(fft2(image))

# %%
plt.imshow(np.abs(centralized_fft),norm=LogNorm(vmin=10**4))
plt.colorbar()

# %%
centralized_fft.shape
# Out:
# (800, 1200)
